# %%
import pandas as pd

ocorrencia_path = '../TP/dados/ocorrencia.csv'    

ocorrencia = pd.read_csv(ocorrencia_path, encoding="latin1", sep=";")
ocorrencia
# Out:
#        codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                  87125               87125               87125
# 1                  87124               87124               87124
# 2                  87123               87123               87123
# 3                  87122               87122               87122
# 4                  87121               87121               87121
# ...                  ...                 ...                 ...
# 13180              28377               28377               28377
# 13181              28375               28375               28375
# 13182              28355               28355               28355
# 13183              28335               28335               28335
# 13184              28256               28256               28256
#
#        codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                   87125               87125                INCIDENTE
# 1                   87124               87124                INCIDENTE
# 2                   87123               87123                INCIDENTE
# 3                   87122               87122                INCIDENTE
# 4                   87121               87121                INCIDENTE
# ...                   ...                 ...                      ...
# 13180               28377               28377                 ACIDENTE
# 13181               28375               28375                 ACIDENTE
# 13182               28355               28355                 ACIDENTE
# 13183               28335               28335                 ACIDENTE
# 13184               28256               28256                 ACIDENTE
#
#       ocorrencia_latitude ocorrencia_longitude      ocorrencia_cidade  \
# 0         -7.219166666666      -39.26944444444      JUAZEIRO DO NORTE
# 1         -18.88361111111      -48.22527777777             UBERLÂNDIA
# 2         -23.43555555555      -46.47305555555              GUARULHOS
# 3         -29.71083333333      -53.69222222222            SANTA MARIA
# 4         -20.81722222222      -49.40694444444  SÃO JOSÉ DO RIO PRETO
# ...                   ...                  ...                    ...
# 13180                 ***                  ***             IMPERATRIZ
# 13181      -23.6122222222              -51.385              APUCARANA
# 13182      -17.2541666667       -43.8536111111               BOCAIÚVA
# 13183      -23.3444444444       -51.0633333333               LONDRINA
# 13184      -22.2180555556       -47.1763888889             MOGI GUAÇU
#
#       ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0                CE  ...     11/05/2025        04:20:00
# 1                MG  ...     08/05/2025        14:00:00
# 2                SP  ...     09/05/2025        18:45:00
# 3                RS  ...     04/05/2025        14:45:00
# 4                SP  ...     10/05/2025        10:00:00
# ...             ...  ...            ...             ...
# 13180            MA  ...     27/01/2007        11:18:00
# 13181            PR  ...     26/01/2007        18:15:00
# 13182            MG  ...     18/01/2007        09:10:00
# 13183            PR  ...     19/01/2007        12:30:00
# 13184            SP  ...     07/01/2007        11:30:00
#
#       investigacao_aeronave_liberada investigacao_status  \
# 0                                SIM          FINALIZADA
# 1                                SIM          FINALIZADA
# 2                                SIM          FINALIZADA
# 3                                SIM          FINALIZADA
# 4                                SIM          FINALIZADA
# ...                              ...                 ...
# 13180                            SIM          FINALIZADA
# 13181                            SIM          FINALIZADA
# 13182                            SIM          FINALIZADA
# 13183                            SIM          FINALIZADA
# 13184                            SIM          FINALIZADA
#
#       divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                             ***                            NÃO
# 1                             ***                            NÃO
# 2                             ***                            NÃO
# 3                             ***                            NÃO
# 4                             ***                            NÃO
# ...                           ...                            ...
# 13180           A-053/CENIPA/2009                            SIM
# 13181           A-021/CENIPA/2010                            SIM
# 13182           A-001/CENIPA/2010                            SIM
# 13183           A-169/CENIPA/2013                            SIM
# 13184           A-112/CENIPA/2012                            SIM
#
#       divulgacao_dia_publicacao total_recomendacoes  \
# 0                           NaN                   0
# 1                           NaN                   0
# 2                           NaN                   0
# 3                           NaN                   0
# 4                           NaN                   0
# ...                         ...                 ...
# 13180                2009-11-16                   2
# 13181                2007-08-15                   1
# 13182                2010-03-19                  11
# 13183                2013-12-16                   1
# 13184                2012-10-17                   2
#
#       total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                              1                     NÃO
# 1                              1                     NÃO
# 2                              1                     NÃO
# 3                              1                     NÃO
# 4                              1                     NÃO
# ...                          ...                     ...
# 13180                          1                     NÃO
# 13181                          1                     NÃO
# 13182                          1                     NÃO
# 13183                          1                     NÃO
# 13184                          1                     NÃO
#
# [13185 rows x 22 columns]

# %%
cell = ocorrencia.iloc[2:5, 2:5]

# ocorrencia_uberlandia = ocorrencia.loc[ocorrencia['ocorrencia_cidade'] == "UBERLÂNDIA", :]
# ocorrencia_uberlandia

# altenativa com shorthand 
ocorrencia_uberlandia = ocorrencia[ocorrencia['ocorrencia_cidade'] == "UBERLÂNDIA"]
ocorrencia_uberlandia
# Out:
#        codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1                  87124               87124               87124
# 28                 87093               87093               87093
# 237                86845               86845               86845
# 284                86715               86715               86715
# 289                86710               86710               86710
# ...                  ...                 ...                 ...
# 12037              40695               40695               40695
# 12133              40212               40212               40212
# 12182              39772               39772               39772
# 12315              38200               38200               38200
# 12394              37238               37238               37238
#
#        codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 1                   87124               87124                INCIDENTE
# 28                  87093               87093                INCIDENTE
# 237                 86845               86845                INCIDENTE
# 284                 86715               86715                INCIDENTE
# 289                 86710               86710                INCIDENTE
# ...                   ...                 ...                      ...
# 12037               40695               40695                INCIDENTE
# 12133               40212               40212                INCIDENTE
# 12182               39772               39772                INCIDENTE
# 12315               38200               38200                INCIDENTE
# 12394               37238               37238                INCIDENTE
#
#       ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade  \
# 1         -18.88361111111      -48.22527777777        UBERLÂNDIA
# 28        -18.88361111111      -48.22527777777        UBERLÂNDIA
# 237       -18.88361111111      -48.22527777777        UBERLÂNDIA
# 284       -18.88361111111      -48.22527777777        UBERLÂNDIA
# 289       -18.88361111111      -48.22527777777        UBERLÂNDIA
# ...                   ...                  ...               ...
# 12037                 NaN                  NaN        UBERLÂNDIA
# 12133                 ***                  ***        UBERLÂNDIA
# 12182                 NaN                  NaN        UBERLÂNDIA
# 12315                 NaN                  NaN        UBERLÂNDIA
# 12394                 NaN                  NaN        UBERLÂNDIA
#
#       ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 1                MG  ...     08/05/2025        14:00:00
# 28               MG  ...     24/04/2025        19:30:00
# 237              MG  ...     26/01/2025        17:15:00
# 284              MG  ...     11/03/2025        12:00:00
# 289              MG  ...     06/03/2025        13:00:00
# ...             ...  ...            ...             ...
# 12037            MG  ...     26/11/2009        01:00:00
# 12133            MG  ...     20/03/2010        12:14:00
# 12182            MG  ...     20/01/2010        18:58:00
# 12315            MG  ...     14/07/2009        13:13:00
# 12394            MG  ...     24/04/2009        12:10:00
#
#       investigacao_aeronave_liberada investigacao_status  \
# 1                                SIM          FINALIZADA
# 28                               SIM          FINALIZADA
# 237                              SIM          FINALIZADA
# 284                              SIM          FINALIZADA
# 289                              SIM          FINALIZADA
# ...                              ...                 ...
# 12037                            SIM          FINALIZADA
# 12133                            SIM          FINALIZADA
# 12182                            SIM          FINALIZADA
# 12315                            SIM          FINALIZADA
# 12394                            SIM          FINALIZADA
#
#       divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 1                             ***                            NÃO
# 28                            ***                            NÃO
# 237                           ***                            NÃO
# 284                           ***                            NÃO
# 289                           ***                            NÃO
# ...                           ...                            ...
# 12037                         ***                            NÃO
# 12133                         ***                            NÃO
# 12182                         ***                            NÃO
# 12315                         ***                            NÃO
# 12394                         ***                            NÃO
#
#       divulgacao_dia_publicacao total_recomendacoes  \
# 1                           NaN                   0
# 28                          NaN                   0
# 237                         NaN                   0
# 284                         NaN                   0
# 289                         NaN                   0
# ...                         ...                 ...
# 12037                       NaN                   0
# 12133                       NaN                   0
# 12182                       NaN                   0
# 12315                       NaN                   0
# 12394                       NaN                   0
#
#       total_aeronaves_envolvidas  ocorrencia_saida_pista
# 1                              1                     NÃO
# 28                             1                     NÃO
# 237                            1                     NÃO
# 284                            1                     NÃO
# 289                            1                     NÃO
# ...                          ...                     ...
# 12037                          1                     NÃO
# 12133                          1                     NÃO
# 12182                          1                     NÃO
# 12315                          1                     NÃO
# 12394                          1                     NÃO
#
# [94 rows x 22 columns]

# %%
# total de ocorrencias
total_ocorrencias = len(ocorrencia)
total_ocorrencias 

# agrupa as cidades por numero de ocorrencias por estado
ocorrencia_por_uf = ocorrencia.groupby('ocorrencia_uf')['codigo_ocorrencia'].count()
ocorrencia_por_uf.sort_values()

# divide pela população do estado => obtem as ocorrencias dos estados per capta

# agrupa as cidades por numero de ocorrencias por ano
# Out:
# ocorrencia_uf
# ***      21
# AP       33
# SE       42
# RN       49
# AL       67
# PB       69
# RO       84
# PI      104
# AC      105
# TO      119
# RR      129
# ES      169
# MA      170
# CE      247
# MS      330
# PE      411
# DF      424
# SC      464
# AM      476
# PA      585
# MT      592
# GO      603
# BA      605
# RS      733
# PR      917
# MG     1077
# RJ     1277
# SP     3283
# Name: codigo_ocorrencia, dtype: int64
